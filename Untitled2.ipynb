# %%
import pandas as pd

# %%
df = pd.read_csv('/home/ozki/Documentos/GeoProyectos/webscraping/ws_vivienda.csv')

# %%
df.shape
# Out:
# (15334, 14)

# %%
df.head()
# Out:
#         fecha                                        descripcion  recamaras  \
# 0  2026-03-22  Renta: $22,500 MXN con mantenimiento incluido\...        NaN
# 1  2026-03-22  Departamento en renta en Valle Poniente con 95...        2.0
# 2  2026-03-22  Departamento en renta en Valle Poniente con 62...        NaN
# 3  2026-03-22  Departamento amueblado en renta en Cordillera ...        2.0
# 4  2026-03-22  Departamento en renta en Zona Valle Poniente c...        2.0
#
#    banos  superficie_m2  precio_actual  \
# 0    NaN           57.0          22500
# 1    2.0           95.0          38000
# 2    NaN           62.0          33000
# 3    2.0           90.0          36000
# 4    2.0           90.0          38500
#
#                                                 link  \
# 0  https://departamento.mercadolibre.com.mx/MLM-4...
# 1  https://departamento.mercadolibre.com.mx/MLM-2...
# 2  https://departamento.mercadolibre.com.mx/MLM-2...
# ...

# %%
df.tail()
# Out:
#             fecha                                        descripcion  \
# 15329  2026-04-02  Edificio recién remodelado estilo Art Deco, en...
# 15330  2026-04-02  Ref: NEX-244762\n\nEsta impresionante propieda...
# 15331  2026-04-02  Se Renta Propiedad Comercial en Avenida Paseo ...
# 15332  2026-04-02  Mira esta magnífica y amplia casona con uso de...
# 15333  2026-04-02  Descripción\n\nCasa en renta o venta en la Col...
#
#        recamaras  banos  superficie_m2  precio_actual  \
# 15329        2.0    NaN          120.0          55000
# 15330        6.0    5.0          229.0         120000
# 15331        NaN    NaN          600.0         300000
# 15332        4.0    2.0          200.0         300000
# 15333        6.0    2.0           91.0         250000
#
#                                                     link  \
# 15329  https://casa.mercadolibre.com.mx/MLM-272230156...
# 15330  https://casa.mercadolibre.com.mx/MLM-475143198...
# ...

# %%
df[df.municipio == 'azcapotzalco'].groupby(['tipo_vivienda','operacion']).size()
# Out:
# tipo_vivienda  operacion
# casas          renta        531
#                venta        524
# departamentos  renta        627
#                venta        579
# dtype: int64
